# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import sklearn
import tarfile
import urllib.request

np.warnings.filterwarnings('ignore', category=np.VisibleDeprecationWarning)

# %%
# Loading in the California Housing Prices Dataset. 
DOWNLOAD_ROOT = "https://raw.githubusercontent.com/ageron/handson-ml2/master/"
HOUSING_PATH = os.path.join("datasets", "housing")
HOUSING_URL = DOWNLOAD_ROOT + "datasets/housing/housing.tgz"

def fetch_housing_data(housing_url=HOUSING_URL, housing_path=HOUSING_PATH):
    if not os.path.isdir(housing_path):
        os.makedirs(housing_path)
    tgz_path = os.path.join(housing_path, "housing.tgz")
    urllib.request.urlretrieve(housing_url, tgz_path)
    housing_tgz = tarfile.open(tgz_path)
    housing_tgz.extractall(path=housing_path)
    housing_tgz.close()
    
fetch_housing_data()

def load_housing_data(housing_path=HOUSING_PATH):
    csv_path = os.path.join(housing_path, "housing.csv")
    return pd.read_csv(csv_path)

# %%
housing = load_housing_data()
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %% [markdown]
# Before we do any splitting or analysis on the data, we first want to check some of the descriptive statistics. This is to ensure that we do not have any uninformative values or null values. Additionally, we want to check for missing data in the dataset. We would want to find a way to deal with the missing values, and in the context of this, possibly impute some of the values.

# %%
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
housing.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %% [markdown]
# We observe that all of the variables here are numeric, except for 1, which is the ocean proximity.

# %%
housing['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %% [markdown]
# ### 1. Data Cleaning and Transformation

# %%
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder

housing_oceanprox = housing[['ocean_proximity']]
onehot_encoder = OneHotEncoder()
housing_onehot = onehot_encoder.fit_transform(housing_oceanprox)
onehot_encoder.categories_
# Out:
# [array(['<1H OCEAN', 'INLAND', 'ISLAND', 'NEAR BAY', 'NEAR OCEAN'],
#        dtype=object)]

# %%
housing_OHoceanprox = pd.DataFrame(housing_onehot.toarray(), columns = ['1HOCEAN','INLAND','ISLAND','NEARBAY','NEAROCEAN'])

# %% [markdown]
# To avoid multicolinearity when using KNN regression, we drop the column NEAROCEAN from the dataset.

# %%
housing_full = pd.concat([housing.drop('ocean_proximity', axis=1), housing_OHoceanprox.iloc[:,:4]], axis=1)
housing_full
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
# Check for any missing values in the dataset.

def missing_value_test(dataset):
    missing_value = np.array(dataset.isnull().sum())
    colnames = dataset.columns
    df = pd.DataFrame(missing_value, index=colnames, columns = ['missing_values']).T
    return(df)

missing_value_test(housing_full)
# Out:
#                 longitude  latitude  housing_median_age  total_rooms  \
# missing_values          0         0                   0            0
#
#                 total_bedrooms  population  households  median_income  \
# missing_values             207           0           0              0
#
#                 median_house_value  1HOCEAN  INLAND  ISLAND  NEARBAY
# missing_values                   0        0       0       0        0

# %% [markdown]
# Looks like we have 207 missing values for the variable total bedrooms. Therefore, we try to impute these values by using some of the techniques and in built functions in Scikit, exploring both the KNN imputer and the Simple Imputer using median. To further analyse these observations, we pick out the indexes.

# %%
incomplete_rows = housing_full[housing_full.isnull().any(axis=1)].index
print(incomplete_rows)
# Out:
# Int64Index([  290,   341,   538,   563,   696,   738,  1097,  1350,  1456,
#              1493,
#             ...
#             19932, 19959, 20046, 20069, 20125, 20267, 20268, 20372, 20460,
#             20484],
#            dtype='int64', length=207)

# %%
from sklearn.impute import SimpleImputer, KNNImputer

# Call the impute functions
median_imputer = SimpleImputer(strategy="median")
KNN_imputer = KNNImputer(n_neighbors = 3)

# %%
# Fit the imputers, and then check the rows that were imputed.
housing_clean_knn = pd.DataFrame(KNN_imputer.fit_transform(housing_full), columns=KNN_imputer.get_feature_names_out())
housing_clean_median = pd.DataFrame(median_imputer.fit_transform(housing_full), columns=KNN_imputer.get_feature_names_out())
housing_clean_median.iloc[incomplete_rows].head()
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 290    -122.16     37.77                47.0       1256.0           435.0
# 341    -122.17     37.75                38.0        992.0           435.0
# 538    -122.28     37.78                29.0       5154.0           435.0
# 563    -122.24     37.75                45.0        891.0           435.0
# 696    -122.10     37.69                41.0        746.0           435.0
#
#      population  households  median_income  median_house_value  1HOCEAN  \
# 290       570.0       218.0         4.3750            161900.0      0.0
# 341       732.0       259.0         1.6196             85100.0      0.0
# 538      3741.0      1273.0         2.5762            173400.0      0.0
# 563       384.0       146.0         4.9489            247100.0      0.0
# 696       387.0       161.0         3.9063            178400.0      0.0
#
#      INLAND  ISLAND  NEARBAY
# 290     0.0     0.0      1.0
# ...

# %%
housing_clean_knn.iloc[incomplete_rows].head()
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 290    -122.16     37.77                47.0       1256.0      241.333333
# 341    -122.17     37.75                38.0        992.0      274.333333
# 538    -122.28     37.78                29.0       5154.0     1299.666667
# 563    -122.24     37.75                45.0        891.0      166.333333
# 696    -122.10     37.69                41.0        746.0      164.666667
#
#      population  households  median_income  median_house_value  1HOCEAN  \
# 290       570.0       218.0         4.3750            161900.0      0.0
# 341       732.0       259.0         1.6196             85100.0      0.0
# 538      3741.0      1273.0         2.5762            173400.0      0.0
# 563       384.0       146.0         4.9489            247100.0      0.0
# 696       387.0       161.0         3.9063            178400.0      0.0
#
#      INLAND  ISLAND  NEARBAY
# 290     0.0     0.0      1.0
# ...

# %% [markdown]
# We can see the numerical values that were imputed using both functions, and for the purposes of KNN regression that we will do later, we choose the dataset that was imputed using KNN. We also would like to scale the dataset, as distance-based models are sensitive to the scale of the features, where instances with larger values would have an abnormally skewed bias towards them.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
std_scaler = StandardScaler() # call the scaler function

# %% [markdown]
# ### 2. k-NN Regression
# Splitting the data into training and test sets first, using a 80:20 ratio.

# %%
# Split the data into the Y dependent variable and X predictor variable;
Y_data = housing_clean_knn['median_house_value']
X_data = housing_clean_knn.drop('median_house_value', axis=1)

# %%
# Create function that will split and scale data, and another function that will return a KNN Regression RMSE
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error
    
def split_scale(X, Y, test_size, random_state = None):
    train_X, test_X, train_Y, test_Y = train_test_split(X, Y, test_size = test_size, random_state=random_state)
    train_Xscale = pd.DataFrame(std_scaler.fit_transform(train_X), columns = std_scaler.get_feature_names_out())
    test_Xscale = pd.DataFrame(std_scaler.fit_transform(test_X), columns = std_scaler.get_feature_names_out())
    return(train_Xscale, test_Xscale, train_Y, test_Y)

def knn_rmse(train_Xscale, test_Xscale, train_Y, test_Y, n_neighbors, distance, alg_type):
    knn_regress_model = KNeighborsRegressor(n_neighbors=n_neighbors, weights=distance, algorithm=alg_type)
    knn_regress_model.fit(train_Xscale, train_Y)
    predicted_train = knn_regress_model.predict(train_Xscale)
    predicted_test = knn_regress_model.predict(test_Xscale)
    train_knn_mse, test_knn_mse = mean_squared_error(predicted_train, train_Y),  mean_squared_error(predicted_test, test_Y)
    train_knn_rmse, test_knn_rmse = np.sqrt(train_knn_mse), np.sqrt(test_knn_mse)
    print('Training RMSE: {}, Test RMSE: {}'.format(train_knn_rmse, test_knn_rmse))

# %% [markdown]
# Split the data into training and test set first. After this, we run a KNN regression on k=5.

# %%
train_Xscale, test_Xscale, train_Y, test_Y = split_scale(X_data, Y_data, 0.2, 5507)
knn_rmse(train_Xscale, test_Xscale, train_Y, test_Y, 5, 'uniform', 'auto')
# Out:
# Training RMSE: 49520.99572124408, Test RMSE: 61735.196229949004

# %% [markdown]
# We observe the RMSE for the basic kNN Regression Model with a uniform distance and 5 neighbours. As expected, the training set does better than the test set in terms of RMSE score.

# %% [markdown]
# The second part requires us to experiment with a selection of columns. First, we explore omitting the categorical variable from the dataset, the ones where we one hot encoded earlier.

# %%
# Numerical Variables only
X_data_num = housing_clean_knn.drop(['median_house_value','1HOCEAN','INLAND','ISLAND','NEARBAY'], axis=1)
data_num = housing_clean_knn.drop(['1HOCEAN','INLAND','ISLAND','NEARBAY'], axis=1)

# %%
from sklearn.model_selection import cross_val_predict
# Tweaked for CV
# 10 Fold Cross Validation for the training set, to choose for best n_neighbours:
def knn_rmse_cv(train_Xscale, test_Xscale, train_Y, test_Y, CV, n_neighbors, distance):
    knn_regress_model = KNeighborsRegressor(n_neighbors=n_neighbors, weights=distance)
    predicted_train_cv = cross_val_predict(knn_regress_model, train_Xscale, train_Y, cv=CV)
    train_knn_mse = mean_squared_error(predicted_train_cv, train_Y)
    train_knn_rmse = np.sqrt(train_knn_mse)
    print('Neighbors ({}) - Training RMSE: {}'.format(n_neighbors, train_knn_rmse))
    return(train_knn_rmse)

# %% [markdown]
# Start with the first model, train just numerical variables.

# %%
train_Xscale, test_Xscale, train_Y, test_Y = split_scale(X_data_num, Y_data, 0.2, 5507)

rmse_exclohv = np.array([])
n_neighbors = np.arange(1, 21)

for i in n_neighbors:
    rmse_exclohv = np.append(rmse_exclohv, knn_rmse_cv(train_Xscale, test_Xscale, train_Y, test_Y, 10, i, 'distance'))
# Out:
# Neighbors (1) - Training RMSE: 76983.6473762097
# Neighbors (2) - Training RMSE: 67783.63161340501
# Neighbors (3) - Training RMSE: 64544.36062408406
# Neighbors (4) - Training RMSE: 62932.18823630271
# Neighbors (5) - Training RMSE: 61950.6411571317
# Neighbors (6) - Training RMSE: 61432.99186807826
# Neighbors (7) - Training RMSE: 61220.49953162411
# Neighbors (8) - Training RMSE: 61129.19218005003
# Neighbors (9) - Training RMSE: 61020.98123257354
# Neighbors (10) - Training RMSE: 60965.71256475472
# Neighbors (11) - Training RMSE: 60961.68020702712
# Neighbors (12) - Training RMSE: 60961.27430596895
# Neighbors (13) - Training RMSE: 61057.42396070992
# Neighbors (14) - Training RMSE: 61056.22273053409
# Neighbors (15) - Training RMSE: 61140.58734953503
# Neighbors (16) - Training RMSE: 61218.185115795764
# Neighbors (17) - Training RMSE: 61287.304621081064
# Neighbors (18) - Training RMSE: 61354.924199990855
# Neighbors (19) - Training RMSE: 61482.773874310944
# ...

# %% [markdown]
# Second model, using the top 5 most positively correlated variables to the median house value.

# %%
# looking at correlation structure:
top5_corr = data_num.corr(method='pearson').loc['median_house_value'].sort_values(ascending=False)[1:6]
top5_corr_names = np.array(top5_corr.index)
top5_corr
# Out:
# median_income         0.688075
# total_rooms           0.134153
# housing_median_age    0.105623
# households            0.065843
# total_bedrooms        0.050252
# Name: median_house_value, dtype: float64

# %%
top_5_trainX, top_5_testX = train_Xscale[top5_corr_names], test_Xscale[top5_corr_names]

rmse_trainval5_corr = np.array([])
n_neighbors = np.arange(1, 21)

for i in n_neighbors:
    rmse_trainval5_corr = np.append(rmse_trainval5_corr, knn_rmse_cv(top_5_trainX, top_5_testX, train_Y, test_Y, 10, i, 'distance'))
# Out:
# Neighbors (1) - Training RMSE: 96502.17152353522
# Neighbors (2) - Training RMSE: 84391.12531259395
# Neighbors (3) - Training RMSE: 80184.9607864675
# Neighbors (4) - Training RMSE: 77920.8708650159
# Neighbors (5) - Training RMSE: 76525.75653618907
# Neighbors (6) - Training RMSE: 75541.29609142471
# Neighbors (7) - Training RMSE: 74807.7617750201
# Neighbors (8) - Training RMSE: 74426.17016846064
# Neighbors (9) - Training RMSE: 74028.53524183136
# Neighbors (10) - Training RMSE: 73689.07956620232
# Neighbors (11) - Training RMSE: 73468.4446492754
# Neighbors (12) - Training RMSE: 73314.25143340667
# Neighbors (13) - Training RMSE: 73088.72117273086
# Neighbors (14) - Training RMSE: 72979.42601549708
# Neighbors (15) - Training RMSE: 72843.09522681274
# Neighbors (16) - Training RMSE: 72778.59242003929
# Neighbors (17) - Training RMSE: 72719.57790715362
# Neighbors (18) - Training RMSE: 72701.71161527149
# Neighbors (19) - Training RMSE: 72694.35454822327
# ...

# %% [markdown]
# 3rd model uses PCA for dimensionality reduction and feature selection, pick the top 5 best PCs.

# %%
# Playing with Principal Components
from sklearn.decomposition import PCA

pca_model = PCA(n_components=2)
pca_model.fit(X_data_num)
f_names = np.array(pca_model.feature_names_in_)
PCs = np.array(['PC1','PC2'])
PC_loadings = pd.DataFrame(pca_model.components_, columns = f_names, index=PCs).T.sort_values('PC1', ascending=False)
top5_attr_pca = np.array(PC_loadings.index[:5])
PC_loadings
# Out:
#                          PC1       PC2
# total_rooms         0.881741 -0.446913
# population          0.418119  0.887354
# total_bedrooms      0.161899  0.050255
# households          0.146609  0.101691
# median_income       0.000120 -0.001254
# longitude           0.000047  0.000425
# latitude           -0.000046 -0.000588
# housing_median_age -0.001819  0.001591

# %%
top_5_trainX, top_5_testX = train_Xscale[top5_attr_pca], test_Xscale[top5_attr_pca]

rmse_trainval5_pc = np.array([])
n_neighbors = np.arange(1, 21)

for i in n_neighbors:
    rmse_trainval5_pc = np.append(rmse_trainval5_pc, knn_rmse_cv(top_5_trainX, top_5_testX, train_Y, test_Y, 10, i, 'distance'))
# Out:
# Neighbors (1) - Training RMSE: 95622.07061854226
# Neighbors (2) - Training RMSE: 83308.65465885126
# Neighbors (3) - Training RMSE: 79056.05963758244
# Neighbors (4) - Training RMSE: 76869.36544825214
# Neighbors (5) - Training RMSE: 75296.39791990613
# Neighbors (6) - Training RMSE: 74453.25795542897
# Neighbors (7) - Training RMSE: 73636.23217817872
# Neighbors (8) - Training RMSE: 73119.10128012374
# Neighbors (9) - Training RMSE: 72753.08276362406
# Neighbors (10) - Training RMSE: 72427.52407521592
# Neighbors (11) - Training RMSE: 72226.53749068212
# Neighbors (12) - Training RMSE: 71999.60372090813
# Neighbors (13) - Training RMSE: 71771.90792365343
# Neighbors (14) - Training RMSE: 71589.22077527747
# Neighbors (15) - Training RMSE: 71457.622610029
# Neighbors (16) - Training RMSE: 71377.29331196717
# Neighbors (17) - Training RMSE: 71263.64259881989
# Neighbors (18) - Training RMSE: 71228.67637367325
# Neighbors (19) - Training RMSE: 71180.77931674862
# ...

# %% [markdown]
# Final model, all variables including the categorical one hot vectors.

# %%
train_Xscale, test_Xscale, train_Y, test_Y = split_scale(X_data, Y_data, 0.2, 5507)

rmse_all = np.array([])
n_neighbors = np.arange(1, 21)

for i in n_neighbors:
    rmse_all = np.append(rmse_all, knn_rmse_cv(train_Xscale, test_Xscale, train_Y, test_Y, 10, i, 'distance'))
# Out:
# Neighbors (1) - Training RMSE: 74917.38562438021
# Neighbors (2) - Training RMSE: 66341.2883016799
# Neighbors (3) - Training RMSE: 63491.42642628416
# Neighbors (4) - Training RMSE: 61921.01463012494
# Neighbors (5) - Training RMSE: 61009.48324944029
# Neighbors (6) - Training RMSE: 60523.23568218418
# Neighbors (7) - Training RMSE: 60300.02220837016
# Neighbors (8) - Training RMSE: 59998.3675510587
# Neighbors (9) - Training RMSE: 59768.84342892809
# Neighbors (10) - Training RMSE: 59681.84278655874
# Neighbors (11) - Training RMSE: 59688.00453147519
# Neighbors (12) - Training RMSE: 59586.536062120096
# Neighbors (13) - Training RMSE: 59660.888834411526
# Neighbors (14) - Training RMSE: 59648.287204590444
# Neighbors (15) - Training RMSE: 59660.61029733585
# Neighbors (16) - Training RMSE: 59773.78647957084
# Neighbors (17) - Training RMSE: 59845.56035750766
# Neighbors (18) - Training RMSE: 59893.5561426147
# Neighbors (19) - Training RMSE: 59948.383089084
# ...

# %% [markdown]
# Comparing the two models, one with the best 5 feature selection using principal components, versus the one where we used all the numerical variables, we see that the training RMSE is significantly lower for the one with all numerical variables compared to the other one. We pick that model to evaluate our test set. Again, we pick k=10 to be the number of neighbours in the KNN regression model.

# %%
model_rmses = pd.DataFrame([rmse_all, rmse_exclohv, rmse_trainval5_corr, rmse_trainval5_pc], index=['All','NumericalOnly','Top5Corr','Top5PC'], columns=n_neighbors).T
model_rmses
# Out:
#              All  NumericalOnly      Top5Corr        Top5PC
# 1   74917.385624   76983.647376  96502.171524  95622.070619
# 2   66341.288302   67783.631613  84391.125313  83308.654659
# 3   63491.426426   64544.360624  80184.960786  79056.059638
# 4   61921.014630   62932.188236  77920.870865  76869.365448
# 5   61009.483249   61950.641157  76525.756536  75296.397920
# 6   60523.235682   61432.991868  75541.296091  74453.257955
# 7   60300.022208   61220.499532  74807.761775  73636.232178
# 8   59998.367551   61129.192180  74426.170168  73119.101280
# 9   59768.843429   61020.981233  74028.535242  72753.082764
# 10  59681.842787   60965.712565  73689.079566  72427.524075
# 11  59688.004531   60961.680207  73468.444649  72226.537491
# 12  59586.536062   60961.274306  73314.251433  71999.603721
# 13  59660.888834   61057.423961  73088.721173  71771.907924
# 14  59648.287205   61056.222731  72979.426015  71589.220775
# 15  59660.610297   61140.587350  72843.095227  71457.622610
# ...

# %%
# Line plot to visualise best k to pick
model_rmses.plot(y=model_rmses.columns)
plt.xticks(n_neighbors)
plt.xlabel('k')
plt.ylabel('RMSE')
plt.title('RMSE on k-Neighbours (All Models)')
# Out:
# Text(0.5, 1.0, 'RMSE on k-Neighbours (All Models)')

# %% [markdown]
# Given the model analysis above, we see that perhaps the best model to use might be using all variables, with k=10 neighbours, seeing how the RMSE flattens off after that point, with no observable model improvement by increasing the number of neighbours. The model applied to the test data gives us a RMSE score of around 61093. Compare that to the baseline model of k=5, this model does better and provides more information.

# %%
train_Xscale, test_Xscale, train_Y, test_Y = split_scale(X_data, Y_data, 0.2, 5507)

final_model_eval = knn_rmse(train_Xscale, test_Xscale, train_Y, test_Y, 10, 'uniform', 'auto')
# Out:
# Training RMSE: 53979.502684277584, Test RMSE: 61093.493350195546

# %% [markdown]
# Using the distance weight metric, weight points are calculated by the inverse of their distance. For the training set, getting a RMSE to be 0 is to be expected because the point identifies/predicts itself, so the RMSE essentially is 0 for all cases. However, this is different for the test case, so we get a interpretable RMSE score. The results in the cell below show us the best model and RMSE.

# %%
final_model_eval = knn_rmse(train_Xscale, test_Xscale, train_Y, test_Y, 10, 'distance', 'auto')
# Out:
# Training RMSE: 0.0, Test RMSE: 60472.94053237417

# %% [markdown]
# ### 3. TSNE
